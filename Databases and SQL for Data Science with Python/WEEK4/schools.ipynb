# %%
import ibm_db
import ibm_db_sa
import sqlalchemy
import pandas as pd

# %reload_ext sql

# %sql ibm_db_sa://wsy87409:3jO6uNH6THqWZg7O@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL

# %% [markdown]
# <font size = "3">Query the database system catalog to retrieve table metadat </font> <br>
# Hint: you can veriy to retrieve list of tables in the database for your shcema

# %%
# %%sql
#
# SELECT TABSCHEMA, TABNAME, CREATE_TIME
#     FROM syscat.tables
#         WHERE TABSCHEMA = 'WSY87409';
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('WSY87409', 'PETSALE', datetime.datetime(2022, 12, 8, 14, 56, 58, 6205)),
#  ('WSY87409', 'TEST', datetime.datetime(2022, 12, 8, 14, 0, 50, 629587)),
#  ('WSY87409', 'TEST_1', datetime.datetime(2022, 12, 8, 14, 8, 15, 236080)),
#  ('WSY87409', 'EMPLOYEES', datetime.datetime(2022, 12, 8, 22, 29, 41, 348782)),
#  ('WSY87409', 'JOB_HISTORY', datetime.datetime(2022, 12, 8, 22, 29, 41, 579077)),
#  ('WSY87409', 'JOBS', datetime.datetime(2022, 12, 8, 22, 29, 41, 846565)),
#  ('WSY87409', 'DEPARTMENTS', datetime.datetime(2022, 12, 8, 22, 29, 42, 99242)),
#  ('WSY87409', 'LOCATIONS', datetime.datetime(2022, 12, 8, 22, 29, 42, 347790)),
#  ('WSY87409', 'PETRESCUE', datetime.datetime(2022, 12, 10, 16, 28, 5, 14848)),
#  ('WSY87409', 'INTERNATIONAL_STUDENT_TEST_SCORES', datetime.datetime(2022, 12, 13, 10, 21, 16, 750364)),
# ...

# %% [markdown]
# <font size = "3">Query the database system catalog to retrieve column metadat </font> <br>
# Hint: the SCHOOLS table containes a large number of columns in the School table

# %%
# %%sql
#
# SELECT * FROM syscat.columns
#     WHERE TABNAME = 'SCHOOLS';
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('WSY87409', 'SCHOOLS', 'RATE_OF_MISCONDUCTS__PER_100_STUDENTS_', 33, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00', '\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('WSY87409', 'SCHOOLS', 'AVERAGE_TEACHER_ATTENDANCE', 34, 'SYSIBM  ', 'VARCHAR', 6, 0, 'OCTETS', 6, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', -1, '\x00\x00\x00\x00\x00\x00', '\x00\x00\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %% [markdown]
# <font size = "3">Retrieve the list of columns in SCHOOLS table and their column type and length

# %%
# %%sql
#
#
# SELECT COLNAME, TYPENAME, LENGTH
#     FROM SYSCAT.COLUMNS
#         WHERE TABNAME = 'CHICAGO_DATA';
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('CA', 'DECIMAL', 4),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR', 22),
#  ('PERCENT_OF_HOUSING_CROWDED', 'DECIMAL', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'DECIMAL', 4),
#  ('PERCENT_AGED_16_UNEMPLOYED', 'DECIMAL', 4),
#  ('PERCENT_AGED_25_WITHOUT_HIGH_SCHOOL_DIPLOMA', 'DECIMAL', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'DECIMAL', 4),
#  ('PER_CAPITA_INCOME_', 'INTEGER', 4),
#  ('HARDSHIP_INDEX', 'DECIMAL', 4),
#  ('COLUMN_0', 'SMALLINT', 2)]

# %% [markdown]
# <font size = "3">P1: how many elementary schools are in the dataset? </font>

# %%
# %%sql
#
# SELECT COUNT(*) from SCHOOlS
#    WHERE "Elementary, Middle, or High School" = 'ES';
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(462,)]

# %% [markdown]
# <font size = "3"> P2: what is the highest safety score and which schools have highest score? <br>

# %%
# %%sql
#
# SELECT MAX(SAFETY_SCORE) FROM SCHOOLS;
#
# SELECT NAME_OF_SCHOOL FROM SCHOOLS
#     where SAFETY_SCORE = (select max(SAFETY_SCORE) from SCHOOLS);
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# Done.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
# ...

# %% [markdown]
# <font size = "3">P5: what are the top 10 schools with the highest "Average student attendance"?

# %%
# %%sql
#
# SELECT  DISTINCT(NAME_OF_SCHOOL),  AVERAGE_STUDENT_ATTENDANCE FROM SCHOOLS
#      ORDER BY AVERAGE_STUDENT_ATTENDANCE DESC NULLS LAST LIMIT 10;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# P6: retrieve the list of 5 schools with lowest average attendance sorted in ascending order based on attendance

# %%
# %%sql
#
#
#
# SELECT NAME_OF_SCHOOL, average_student_attendance FROM SCHOOLS
#     order by average_student_attendance LIMIT 5;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# **Alternatively:**

# %%
# %%sql
#
# SELECT NAME_OF_SCHOOL, average_student_attendance FROM SCHOOLS
#     order by average_student_attendance
#         fetch first 5 rows only;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# P6: remove the '%' sign from the above result set for average studen attendance column, For this, we use **`REPLACE`** statement.

# %%
# %%sql
#
#
#
# SELECT NAME_OF_SCHOOL, REPLACE(average_student_attendance, '%','') FROM SCHOOLS
#     order by average_student_attendance
#         fetch first 5 rows only;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %% [markdown]
# <font size = "3">P7: which school have average student attendance lower than 70%? <br>
# <font size = "2">Hint: the datatype of the *average_student_attendace* column is `varchar`. So we can not use it as it is in the `where` statement
# for a numeric comparison, we have to first `CAST(col_name, as DOUBLE)` OR simply `DECIMAL(col_name)`.

# %%
# %%sql
#
# SELECT NAME_OF_SCHOOL, average_student_attendance FROM SCHOOLS
#     WHERE CAST( REPLACE(average_student_attendance, '%', '') AS DOUBLE) < 70
#         ORDER BY average_student_attendance;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %% [markdown]
# **Alternatively:**

# %%
# %%sql
#
# SELECT NAME_OF_SCHOOL, average_student_attendance FROM SCHOOLS
#     WHERE DECIMAL( REPLACE(average_student_attendance, '%', '')) < 70
#         ORDER BY average_student_attendance;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %% [markdown]
# P8: get the total *college enrollment* for each community area.

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) AS total_enrollment
#     FROM SCHOOLS
#         GROUP BY COMMUNITY_AREA_NAME;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('ALBANY PARK', 6864),
#  ('ARCHER HEIGHTS', 4823),
#  ('ARMOUR SQUARE', 1458),
#  ('ASHBURN', 6483),
#  ('AUBURN GRESHAM', 4175),
#  ('AUSTIN', 10933),
#  ('AVALON PARK', 1522),
#  ('AVONDALE', 3640),
#  ('BELMONT CRAGIN', 14386),
#  ('BEVERLY', 1636),
#  ('BRIDGEPORT', 3167),
#  ('BRIGHTON PARK', 9647),
#  ('BURNSIDE', 549),
#  ('CALUMET HEIGHTS', 1568),
#  ('CHATHAM', 5042),
#  ('CHICAGO LAWN', 7086),
#  ('CLEARING', 2085),
#  ('DOUGLAS', 4670),
#  ('DUNNING', 4568),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('EDGEWATER', 4600),
#  ('EDISON PARK', 910),
#  ('ENGLEWOOD', 6832),
#  ('FOREST GLEN', 1431),
#  ('FULLER PARK', 531),
#  ('GAGE PARK', 9915),
#  ('GARFIELD RIDGE', 4552),
#  ('GRAND BOULEVARD', 2809),
#  ('GREATER GRAND CROSSING', 4051),
#  ('HEGEWISCH', 963),
#  ('HERMOSA', 3975),
#  ('HUMBOLDT PARK', 8620),
# ...

# %% [markdown]
# P9: get hte 5 community areas with the least total college enrollment sorted in ascending order.

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) AS total_enrollment
#     FROM SCHOOLS
#         GROUP BY COMMUNITY_AREA_NAME
#             ORDER BY total_enrollment LIMIT 5;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %% [markdown]
# **Alternatively:**

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME, SUM(COLLEGE_ENROLLMENT) AS total_enrollment
#     FROM SCHOOLS
#         GROUP BY COMMUNITY_AREA_NAME
#             ORDER BY total_enrollment asc
#                 fetch first 5 rows only
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %% [markdown]
# P10: list 5 schools with lowest saftey score.

# %%
# %%sql
#
#
#
# SELECT NAME_OF_SCHOOL, SAFETY_SCORE FROM SCHOOLS
#     ORDER BY SAFETY_SCORE
#         fetch first 5 rows only;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Edmond Burke Elementary School', 1),
#  ("Luke O'Toole Elementary School", 5),
#  ('George W Tilton Elementary School', 6),
#  ('Foster Park Elementary School', 11),
#  ('Emil G Hirsch Metropolitan High School', 13)]

# %% [markdown]
# P11: get the hardship index for community area which has *college enrollement* of  4368

# %%
# %%sql
#
# SELECT S.COMMUNITY_AREA_NAME, S.COLLEGE_ENROLLMENT, CD.HARDSHIP_INDEX
#     FROM SCHOOLS AS S, CHICAGO_DATA AS CD
#         WHERE S.COMMUNITY_AREA_NUMBER = CD.CA AND  S.COLLEGE_ENROLLMENT = 4368;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('NORTH CENTER', 4368, Decimal('6.0'))]

# %% [markdown]
# **Alternatively:**

# %%
# %%sql
#
# select HARDSHIP_INDEX, ca
#     from SCHOOLS S, CHICAGO_DATA CD
#         WHERE S.COMMUNITY_AREA_NUMBER = CD.CA AND  S.COLLEGE_ENROLLMENT = 4368
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(Decimal('6.0'), Decimal('5.0'))]

# %% [markdown]
# P12: get the hardship index for the community area which has the school with the highest enrollment

# %%
# %%sql
#
# SELECT CD.ca, S.COMMUNITY_AREA_NAME, CD.HARDSHIP_index, S.COLLEGE_ENROLLMENT
#     FROM SCHOOLS AS S, CHICAGO_DATA AS CD
#         WHERE S.COMMUNITY_AREA_NUMBER = CD.CA
#         AND  S.COLLEGE_ENROLLMENT = (select max(COLLEGE_ENROLLMENT) from SCHOOLS);
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(Decimal('5.0'), 'NORTH CENTER', Decimal('6.0'), 4368)]

# %% [markdown]
# **Alternatively:**

# %%
# %%sql
#
# select CA, community_area_name, Hardship_index
# from CHICAGO_DATA
#         where CA in (select community_area_number from SCHOOLS order by college_enrollment desc limit 1)
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(Decimal('5.0'), 'North Center', Decimal('6.0'))]

# %%
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(5,)]
