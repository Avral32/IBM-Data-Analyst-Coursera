# %%
import ibm_db
import ibm_db_sa
import sqlalchemy
import pandas as pd

# %reload_ext sql

# %sql ibm_db_sa://wsy87409:3jO6uNH6THqWZg7O@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL

# %% [markdown]
# <font size="2"> In oder to create a table in the Db2 database to store the dataset, the `PERSIS` command in `SQL` *magic*
# simplifies the process of the table creation and writing the data from the `Pandas` dataframe into the table.

# %%
#chicago_data = pd.read_csv('https://data.cityofchicago.org/resource/jcxq-k9xf.csv')
#chicago_data.to_csv("chicago.csv")
##%sql persist data

# %%
# %sql SELECT * from CHICAGO_DATA
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(0, Decimal('1.0'), 'Rogers Park', Decimal('7.7'), Decimal('23.6'), Decimal('8.7'), Decimal('18.2'), Decimal('27.5'), 23939, Decimal('39.0')),
#  (1, Decimal('2.0'), 'West Ridge', Decimal('7.8'), Decimal('17.2'), Decimal('8.8'), Decimal('20.8'), Decimal('38.5'), 23040, Decimal('46.0')),
#  (2, Decimal('3.0'), 'Uptown', Decimal('3.8'), Decimal('24.0'), Decimal('8.9'), Decimal('11.8'), Decimal('22.2'), 35787, Decimal('20.0')),
#  (3, Decimal('4.0'), 'Lincoln Square', Decimal('3.4'), Decimal('10.9'), Decimal('8.2'), Decimal('13.4'), Decimal('25.5'), 37524, Decimal('17.0')),
#  (4, Decimal('5.0'), 'North Center', Decimal('0.3'), Decimal('7.5'), Decimal('5.2'), Decimal('4.5'), Decimal('26.2'), 57123, Decimal('6.0')),
# ...

# %% [markdown]
# P2: How many community areas in Chicago have a hardship index greater than 50.0?

# %%
# %sql SELECT COUNT(*) FROM CHICAGO_DATA \
    WHERE hardship_index > 50;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(38,)]

# %%
P3: what is the maximum value of the hardship index in this dataset? <br>

# %%
# %sql SELECT MAX(hardship_index) FROM CHICAGO_DATA;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [(Decimal('1.0'),)]

# %% [markdown]
# P4: which community area which has the highest hard_ship index?

# %%
# %sql SELECT community_area_name FROM CHICAGO_DATA \
    WHERE hardship_index = (select max(hardship_index) from CHICAGO_DATA);
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Riverdale',)]

# %% [markdown]
# P5: Which chicago community area have per-capita incomes greater than $60,000

# %%
# %sql SELECT community_area_name, per_capita_income_ FROM CHICAGO_DATA \
    WHERE per_capita_income_ >60000;
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# [('Lake View', 60058),
#  ('Lincoln Park', 71551),
#  ('Near North Side', 88669),
#  ('Loop', 65526)]

# %% [markdown]
# P6: create a scatte plot using the vatiables *per_capita_income* and *hardship index*.

# %%
import seaborn as sns
import numpy as np
df = %sql SELECT per_capita_income_, hardship_index FROM CHICAGO_DATA

data = df.DataFrame()
data["hardship_index"].astype(np.float64)
data["per_capita_income_"].astype(np.float64)

#sns.set_style('whitegrid')
#plot= sns.jointplot(data = data, x = "hardship_index", y = "per_capita_income_")
#plot.show()
# Out:
#  * ibm_db_sa://wsy87409:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb;security=SSL
# Done.
# 0     23939.0
# 1     23040.0
# 2     35787.0
# 3     37524.0
# 4     57123.0
#        ...
# 73    34381.0
# 74    27149.0
# 75    25828.0
# 76    33385.0
# 77    28202.0
# Name: per_capita_income_, Length: 78, dtype: float64
